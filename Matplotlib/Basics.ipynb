# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("January_23.csv")
df.head()
# Out:
#    order_id   orderDate  customer_id  Resturant_ID  Fooditem  quantity  \
# 0    254001  01-01-2023           30           211      2142         4
# 1    254002  01-01-2023           25           214      2152         7
# 2    254003  01-01-2023           28           212      2145         2
# 3    254004  01-01-2023            4           213      2149         2
# 4    254005  01-01-2023           30           211      2141         4
#
#   deliver_status payment_method
# 0      Delivered            COD
# 1      Delivered            COD
# 2      Delivered            UPI
# 3      Delivered            UPI
# 4      Cancelled            UPI

# %%
df.tail()
# Out:
#      order_id   orderDate  customer_id  Resturant_ID  Fooditem  quantity  \
# 621    254622  31-01-2023           13           214      2154         6
# 622    254623  31-01-2023           13           213      2150         6
# 623    254624  31-01-2023            4           217      2165         9
# 624    254625  31-01-2023           25           212      2145        10
# 625    254626  31-01-2023           28           211      2144         7
#
#     deliver_status payment_method
# 621      Delivered            COD
# 622      Delivered            UPI
# 623      Delivered            COD
# 624      Delivered           Card
# 625      Delivered            UPI

# %%
df.columns
# Out:
# Index(['order_id', 'orderDate', 'customer_id', 'Resturant_ID', 'Fooditem',
#        'quantity', 'deliver_status', 'payment_method'],
#       dtype='object')

# %%
plt.bar(df["payment_method"], df["customer_id"])

plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("CSV Data Plot")
plt.show()
